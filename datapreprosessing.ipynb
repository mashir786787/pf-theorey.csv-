# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv",sep=",")

# %%
df.head(4)
# Out:
#     Date_year   open  high_value    low  close  adjclose  total_volume ticker
# 0  10/21/2021  10.06      10.060  10.03  10.03     10.03       9815256  XFINU
# 1  10/22/2021  10.03      10.045  10.03  10.03     10.03        805740  XFINU
# 2  10/25/2021  10.03      10.150  10.03  10.07     10.07        114683  XFINU
# 3  10/26/2021  10.00      10.100  10.00  10.09     10.09          3104  XFINU

# %%
df.tail(3)
# Out:
#      Date_year     open  high_value      low    close  adjclose  total_volume  \
# 666  6/17/2024  10.7462     10.7462  10.7462  10.7462   10.7462             0
# 667  6/18/2024  10.7462     10.7462  10.7462  10.7462   10.7462             0
# 668  6/20/2024  10.7462     10.7462  10.7462  10.7462   10.7462             0
#
#     ticker
# 666  XFINU
# 667  XFINU
# 668  XFINU

# %%
df.sample(8)
# Out:
#       Date_year     open  high_value      low    close  adjclose  \
# 174    7/1/2022   9.9701      9.9701   9.9701   9.9701    9.9701
# 578    2/9/2024  10.7300     10.7300  10.7300  10.7300   10.7300
# 659    6/6/2024  10.7462     10.7462  10.7462  10.7462   10.7462
# 525  11/22/2023  10.7070     10.7070  10.7070  10.7070   10.7070
# 81    2/16/2022  10.0600     10.0600  10.0600  10.0600   10.0600
# 644   5/15/2024  10.7462     10.7462  10.7462  10.7462   10.7462
# 142   5/16/2022  10.0200     10.0200  10.0200  10.0200   10.0200
# 442   7/27/2023  10.4700     10.4700  10.4700  10.4700   10.4700
#
#      total_volume ticker
# 174             0  XFINU
# 578             0  XFINU
# 659             0  XFINU
# 525             0  XFINU
# 81           3090  XFINU
# 644             0  XFINU
# 142             0  XFINU
# 442             0  XFINU

# %%
df.columns
# Out:
# Index(['Date_year', 'open', 'high_value', 'low', 'close', 'adjclose',
#        'total_volume', 'ticker'],
#       dtype='object')

# %%
df.rename(columns={"Date_year":"year","high_value":"value","total_volume":"volume"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      669 non-null    object
#  1   open      667 non-null    float64
#  2   value     667 non-null    float64
#  3   low       666 non-null    float64
#  4   close     667 non-null    float64
#  5   adjclose  668 non-null    float64
#  6   volume    669 non-null    int64
#  7   ticker    669 non-null    object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 41.9+ KB

# %%
df.columns
# Out:
# Index(['year', 'open', 'value', 'low', 'close', 'adjclose', 'volume',
#        'ticker'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   year      669 non-null    object
#  1   open      667 non-null    float64
#  2   value     667 non-null    float64
#  3   low       666 non-null    float64
#  4   close     667 non-null    float64
#  5   adjclose  668 non-null    float64
#  6   volume    669 non-null    int64
#  7   ticker    669 non-null    object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 41.9+ KB

# %%
df.shape
# Out:
# (669, 8)

# %%
z = df.describe()

# %%
z = df.describe(include ="all")

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df[["close","low"]]
# Out:
#        close      low
# 0    10.0300  10.0300
# 1    10.0300  10.0300
# 2    10.0700  10.0300
# 3    10.0900  10.0000
# 4    10.0600  10.0400
# 5    10.0700  10.0700
# 6    10.0700  10.0500
# 7    10.0900  10.0900
# 8    10.0900  10.0700
# 9    10.0900  10.0603
# 10   10.0800  10.0404
# 11   10.0800  10.0000
# 12   10.0800  10.0500
# 13   10.0800  10.0500
# 14   10.0751  10.0751
# 15   10.0751  10.0751
# 16   10.0800  10.0800
# 17   10.0750  10.0700
# 18   10.0900  10.0734
# 19   10.0900  10.0900
# 20   10.0900  10.0900
# 21   10.0900  10.0600
# 22   10.0900  10.0900
# 23   10.1000  10.1000
# 24   10.0900  10.0900
# 25   10.0900  10.0900
# 26   10.1000  10.1000
# 27   10.1201  10.0700
# 28   10.1000  10.0900
# 29   10.1000  10.1000
# 30   10.1000  10.1000
# 31   10.0500  10.0500
# 32   10.0500  10.0500
# 33   10.0500  10.0500
# 34   10.0600  10.0500
# 35   10.0000  10.0000
# 36   10.0500  10.0500
# 37   10.0500  10.0500
# 38   10.0600  10.0300
# 39   10.0650  10.0109
# ...

# %%
a.loc[["top","mean"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 a.loc[["top","mean"]]
#
# NameError: name 'a' is not defined

# %%
a.iloc[[1,4,6]]
# Out:
#        year       open      value        low      close   adjclose  \
# unique  669        NaN        NaN        NaN        NaN        NaN
# mean    NaN  10.341184  10.347496  10.333143  10.339786  10.339891
# min     NaN   9.800000   9.800000   9.580000   9.800000   9.800000
#
#               volume ticker
# unique           NaN      1
# mean    19385.297459    NaN
# min         0.000000    NaN

# %%
df["close"].mean()
# Out:
# 10.339785541854573

# %%
df["close"].mode
# Out:
# <bound method Series.mode of 0      10.0300
# 1      10.0300
# 2      10.0700
# 3      10.0900
# 4      10.0600
# 5      10.0700
# 6      10.0700
# 7      10.0900
# 8      10.0900
# 9      10.0900
# 10     10.0800
# 11     10.0800
# 12     10.0800
# 13     10.0800
# 14     10.0751
# 15     10.0751
# 16     10.0800
# 17     10.0750
# 18     10.0900
# 19     10.0900
# 20     10.0900
# 21     10.0900
# 22     10.0900
# 23     10.1000
# 24     10.0900
# 25     10.0900
# 26     10.1000
# 27     10.1201
# 28     10.1000
# 29     10.1000
# 30     10.1000
# 31     10.0500
# 32     10.0500
# 33     10.0500
# 34     10.0600
# 35     10.0000
# 36     10.0500
# 37     10.0500
# 38     10.0600
# 39     10.0650
# 40     10.0600
# 41     10.0200
# 42     10.0300
# 43     10.1400
# 44     10.2000
# 45     10.2000
# 46     10.1500
# 47     10.1500
# 48     10.1500
# 49     10.1500
# 50     10.1500
# 51     10.1400
# 52     10.1400
# 53     10.1300
# 54     10.1700
# 55     10.1200
# 56     10.1200
# ...

# %%
df["close"].median
# Out:
# <bound method Series.median of 0      10.0300
# 1      10.0300
# 2      10.0700
# 3      10.0900
# 4      10.0600
# 5      10.0700
# 6      10.0700
# 7      10.0900
# 8      10.0900
# 9      10.0900
# 10     10.0800
# 11     10.0800
# 12     10.0800
# 13     10.0800
# 14     10.0751
# 15     10.0751
# 16     10.0800
# 17     10.0750
# 18     10.0900
# 19     10.0900
# 20     10.0900
# 21     10.0900
# 22     10.0900
# 23     10.1000
# 24     10.0900
# 25     10.0900
# 26     10.1000
# 27     10.1201
# 28     10.1000
# 29     10.1000
# 30     10.1000
# 31     10.0500
# 32     10.0500
# 33     10.0500
# 34     10.0600
# 35     10.0000
# 36     10.0500
# 37     10.0500
# 38     10.0600
# 39     10.0650
# 40     10.0600
# 41     10.0200
# 42     10.0300
# 43     10.1400
# 44     10.2000
# 45     10.2000
# 46     10.1500
# 47     10.1500
# 48     10.1500
# 49     10.1500
# 50     10.1500
# 51     10.1400
# 52     10.1400
# 53     10.1300
# 54     10.1700
# 55     10.1200
# 56     10.1200
# ...

# %%
df.isnull()
# Out:
#       year   open  value    low  close  adjclose  volume  ticker
# 0    False  False  False  False  False     False   False   False
# 1    False  False  False  False  False     False   False   False
# 2    False  False  False  False  False     False   False   False
# 3    False  False  False  False  False     False   False   False
# 4    False  False  False  False  False     False   False   False
# 5    False  False  False  False  False     False   False   False
# 6    False  False  False  False  False     False   False   False
# 7    False  False  False  False  False     False   False   False
# 8    False  False  False  False  False     False   False   False
# 9    False  False  False  False  False     False   False   False
# 10   False  False  False  False  False     False   False   False
# 11   False  False  False  False  False     False   False   False
# 12   False  False  False  False  False     False   False   False
# ...

# %%
df.isnull().sum()
# Out:
# year        0
# open        2
# value       2
# low         3
# close       2
# adjclose    1
# volume      0
# ticker      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['ticker'].value_counts().plot(kind="bar",title=" graph",color="red")
# Out:
# <Axes: title={'center': 'close graph'}, xlabel='ticker'>

# %%
df.groupby("close").describe()
# Out:
#          open                                                         \
#         count       mean           std      min        25%       50%
# close
# 9.8000    1.0   9.800000           NaN   9.8000   9.800000   9.80000
# 9.9700    5.0   9.972000  4.471812e-03   9.9700   9.970000   9.97000
# 9.9701    3.0   9.970067  5.781355e-05   9.9700   9.970050   9.97010
# 9.9715    2.0   9.960750  1.520321e-02   9.9500   9.955375   9.96075
# 9.9800   12.0   9.984166  9.962278e-03   9.9800   9.980000   9.98000
# 9.9900    4.0   9.995000  5.773635e-03   9.9900   9.990000   9.99500
# 9.9909    1.0   9.990900           NaN   9.9909   9.990900   9.99090
# 10.0000  38.0   9.999474  3.244503e-03   9.9800  10.000000  10.00000
# 10.0100   4.0  10.035000  4.999972e-02  10.0100  10.010000  10.01000
# 10.0165   5.0  10.016500  0.000000e+00  10.0165  10.016500  10.01650
# 10.0200  30.0  10.019337  4.482959e-03  10.0001  10.020000  10.02000
# ...

# %%
df.to_csv("data2.csv")
